# %%
# Importing Required Libraries
import numpy as np
import matplotlib.pyplot as plt

# Generating time data using arange function from numpy
time = np.arange(-3*np.pi, 3*np.pi, 1) #np.arange(start, stop, step)

# Finding amplitude at each time
amplitude = np.sin(time)

# Plotting time vs amplitude using plot function from pyplot
plt.stem(time, amplitude)

# Settng title for the plot in blue color
plt.title('Sine Wave', color='b')

# Setting x axis label for the plot
plt.xlabel('Time'+ r'$\rightarrow$')

# Setting y axis label for the plot
plt.ylabel('Sin(time) '+ r'$\rightarrow$')

# Showing grid
plt.grid()

# Highlighting axis at x=0 and y=0
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

# Finally displaying the plot
plt.show()

# %% [markdown]
# #1. Introduction
#  This code generates and plots a sine wave using Python with the help of two popular libraries: NumPy and Matplotlib. The primary goal is to illustrate the process of creating a sine wave, visualizing it, and customizing the plot for better clarity.
# #2. Code Components
#   2.1 Importing Libraries
#
#      In this section, the necessary libraries, NumPy and Matplotlib, are imported.NumPy provides numerical operations, and Matplotlib is used for plotting.
#   2.2 Generating Time Data
#
#      The np.arange() function creates an array of time values ranging from -3 * pi to 3 * pi with a step size of 0.01. This array is used as the x-axis for the sine wave.
#   2.3 Finding Amplitude
#
#      The np.sin() function is applied to the time array, producing an array of corresponding sine values. This represents the y-axis values for the sine wave.
#   2.4 Plotting
#
#      The plt.plot() function is used to create a plot of time against amplitude. This line plot represents the sine wave.
#
#   2.5 Customizing Plot
#
#       Several plot customization options are applied here, such as setting the title, x-axis label, y-axis label, displaying the grid, and highlighting the axes at x=0 and y=0.
#   2.6 Displaying the Plot
#
#       Finally, the plt.show() function is called to display the sine wave plot.
#
# #3. Conclusion
#      This code successfully generates and visualizes a sine wave, showcasing the utilization of NumPy and Matplotlib for numerical computation and plotting. The customization options enhance the clarity of the plot for better interpretation.

# %%
from scipy import signal
import matplotlib.pyplot as plot
import numpy as np

t = np.linspace(0, 1, 100, endpoint=True)

# Plot the sawtooth wave
plot.stem(t, signal.sawtooth(2 * np.pi * 5 * t))

# Give x, y, title axis label
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.title('Sawtooth Signal')

plot.axhline(y=0, color='k')

# Display
plot.show()

# %% [markdown]
# # 1. **Introduction**
#
#    This report describes a Python program designed to generate and visually represent a sawtooth wave using the scipy.signal module for signal processing and the matplotlib.pyplot module for plotting. The code utilizes the stem function for a more detailed representation of individual data points.
#
# #2. Code Components
#
#   2.1 Importing Libraries
#
#     In this section, the necessary libraries are imported: scipy.signal for sawtooth wave generation and matplotlib.pyplot for plotting.
#   2.2 Generating Time Data
#
#     The np.linspace() function is used to generate an array t representing time values from 0 to 1 with 100 points.
#
#   2.3 Generating and Plotting the Sawtooth Wave with Stems
#
#     The sawtooth wave is generated using signal.sawtooth(), and the plot.stem() function is used to emphasize individual data points in the plot.
#
#   2.4 Plot Customization
#
#     The x-axis label, y-axis label, and plot title are set to provide context and clarity.A horizontal line is added at y=0 for reference.
#
#   2.5 Displaying the Plot
#
#     The show() function displays the generated sawtooth wave plot with stems.
#
# #3. Conclusion
#
#     This Python program successfully generates and plots a sawtooth wave using the scipy.signal module and emphasizes individual data points with stems, providing a detailed representation of the waveform. The plot includes essential labels and a baseline reference line for better interpretation.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate time values
t = np.linspace(-5, 5, 11)  # 11 points from -5 to 5

# Create an impulse function
impulse = np.zeros_like(t)
impulse[len(t)//2] = 1  # Setting the middle point to 1 (impulse)

# Plotting the impulse function
plt.stem(t, impulse, basefmt='b-', use_line_collection=True)
plt.title('Impulse Function')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-57-ce29523c004d>:12: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(t, impulse, basefmt='b-', use_line_collection=True)

# %% [markdown]
# # 1. **Introduction**
#
#     This report describes a Python program designed to generate and visualize an impulse function. The code uses the matplotlib.pyplot and numpy libraries for plotting and numerical operations, respectively. The impulse function is created to represent a single spike at the center of the time axis.
#
# # 2. Code Components
#     2.1 Importing Libraries
#
#     In this section, necessary libraries are imported: matplotlib.pyplot for plotting and numpy for numerical operations.
#
#     2.2 Generating Time Data
#
#     The np.linspace() function generates an array t representing time values from -5 to 5 with 11 points.
#
#     2.3 Creating an Impulse Function
#
#     An array impulse is created with zeros, and its middle point is set to 1, creating an impulse function with a single spike.
#
#     2.4 Plotting the Impulse Function
#
#     The plt.stem() function is used to plot the impulse function. Blue stems are used for representation, and use_line_collection=True enhances performance.
#
#     2.5 Plot Customization
#
#     This section sets the title, x-axis label, y-axis label, and enables the grid for better visualization.
#
#     2.6 Displaying the Plot
#
#     The show() function displays the generated plot of the impulse function.
#
# # 3. Conclusion
#     This Python program successfully generates and plots an impulse function using the matplotlib.pyplot and numpy libraries. The plot includes a single spike representing the impulse at the center of the time axis. Customizations such as labels and grid lines enhance the interpretability of the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

# Generate time values
t = np.linspace(0, 1, 100, endpoint=False)
# Generate time values
t_positive = np.linspace(0, 1, 100, endpoint=False)
t_negative = np.linspace(-1, 0, 100, endpoint=False)


# Generate periodic triangular waveform
frequency = 5  # Adjust the frequency of the waveform
amplitude = 1  # Adjust the amplitude of the waveform
positive_triangular = amplitude * signal.sawtooth(2 * np.pi * frequency * t_positive, width=0.5)
negative_triangular = -amplitude * signal.sawtooth(2 * np.pi * frequency * np.abs(t_negative), width=0.5)


# Plotting the triangular waveform
plt.stem(t, triangular_waveform)
plt.title('Periodic Triangular Waveform')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

# Generate time values
t_positive = np.linspace(0, 1, 1000, endpoint=False)
t_negative = np.linspace(-1, 0, 1000, endpoint=False)

# Generate positive and negative triangular waveforms
frequency = 5  # Adjust the frequency of the waveform
amplitude = 1  # Adjust the amplitude of the waveform

positive_triangular = amplitude * signal.sawtooth(2 * np.pi * frequency * t_positive, width=0.5)
negative_triangular = -amplitude * signal.sawtooth(2 * np.pi * frequency * np.abs(t_negative), width=0.5)

# Concatenate positive and negative waveforms
triangular_waveform = np.concatenate((negative_triangular, positive_triangular))

# Generate combined time values
t_combined = np.linspace(-1, 1, 2000, endpoint=False)

# Plotting the combined triangular waveform
plt.plot(t_combined, triangular_waveform)
plt.title('Triangular Waveform (Positive and Negative Sides)')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

# Generate time values
t_positive = np.linspace(0, 1, 100, endpoint=False)
t_negative = np.linspace(-1, 0, 100, endpoint=False)

# Generate positive and negative triangular waveforms
frequency = 5  # Adjust the frequency of the waveform
amplitude = 1  # Adjust the amplitude of the waveform

positive_triangular = amplitude * signal.sawtooth(2 * np.pi * frequency * t_positive, width=0.5)
negative_triangular = -amplitude * signal.sawtooth(2 * np.pi * frequency * np.abs(t_negative), width=0.5)

# Concatenate positive and negative waveforms
triangular_waveform = np.concatenate((negative_triangular, positive_triangular))

# Generate combined time values
t_combined = np.linspace(-1, 1, 2000, endpoint=False)

# Plotting the combined triangular waveform
plt.stem(t_combined, triangular_waveform)
plt.title('Triangular Waveform (Positive and Negative Sides)')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-8ee48830dc64> in <cell line: 23>()
#      21
#      22 # Plotting the combined triangular waveform
# ---> 23 plt.stem(t_combined, triangular_waveform)
#      24 plt.title('Triangular Waveform (Positive and Negative Sides)')
#      25 plt.xlabel('Time')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     382             # Early return in the simple, non-deprecated case (much faster than
#     383             # calling bind()).
# --> 384             return func(*inner_args, **inner_kwargs)
#     385         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386         if is_varargs and arguments.get(name):
#
# ...
